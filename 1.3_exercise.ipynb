# %% [markdown]
# # Advanced Data Structures and Functions - Exercises

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# ### Exercise 1: Dictionary Basics

# %%
movie = {
    'title' : "Beyaz Hap",
    'director' : "Efe Aydal",
    'year' : 2018,
    'genre' : "awakenings"
}
print(movie['title'])
movie['raiting'] = 8.5
movie['year'] = 2019
del movie['genre']
movie
# Out:
# Beyaz Hap
# {'title': 'Beyaz Hap', 'director': 'Efe Aydal', 'year': 2019, 'raiting': 8.5}

# %% [markdown]
# ### Exercise 2: Dictionary Methods

# %%
movie.keys()
# Out:
# dict_values(['Beyaz Hap', 'Efe Aydal', 2019, 8.5])

# %%
movie.values()
# Out:
# dict_values(['Beyaz Hap', 'Efe Aydal', 2019, 8.5])

# %%
movie.items()
# Out:
# dict_items([('title', 'Beyaz Hap'), ('director', 'Efe Aydal'), ('year', 2019), ('raiting', 8.5)])

# %%
print(movie.get(  'producer' , 'unknown'))
# Out:
# unknown

# %%
print('director' in movie)
# Out:
# True

# %% [markdown]
# ### Exercise 3: Nested Dictionaries

# %%
employees = {
    "Alice": {"role": "Developer", "salary": 80000},
    "Bob": {"role": "Designer", "salary": 75000}
}
employees['Alice']['role']
employees['Bob']['salary'] = 78000
employees['Charlie'] = {'role' : "Manager",  'salary' : 90000}
employees
# Out:
# {'Alice': {'role': 'Developer', 'salary': 80000},
#  'Bob': {'role': 'Designer', 'salary': 78000},
#  'Charlie': {'role': 'Manager', 'salary': 90000}}

# %% [markdown]
# ### Sets

# %% [markdown]
# ### Exercise 5: Set Operations

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7, 8}
print (set1.union (set2))
print(set1.intersection(set2))
print(set1.difference(set2))
print(set2.difference(set1))

print(set1.symmetric_difference(set2))


SymmetricDifference = (set1.union (set2)).difference(set1.intersection(set2))
print(SymmetricDifference)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}
# {4, 5}
# {1, 2, 3}
# {8, 6, 7}
# {1, 2, 3, 6, 7, 8}
# {1, 2, 3, 6, 7, 8}

# %% [markdown]
# ### Exercise 4: Set Creation and Properties

# %%
numbers = [10, 10,10,20,20,30,30, 20, 30, 20, 40, 10, 50]
num = set(numbers)
num.add(60)
num.add(10)#nothimg happend
num
# Out:
# {10, 20, 30, 40, 50, 60}

# %% [markdown]
# ### Functions

# %% [markdown]
# ### Exercise 6: Basic Function

# %%
def print_greeting ():
    print("Hello World!")

print_greeting()
# Out:
# Hello World!

# %% [markdown]
# ### Exercise 7: Function with Arguments and Return Value

# %%
def calculate_area (width ,height):
    area = width * height
    return area

calculate_area(width=5,height=10)
# Out:
# 50

# %%
def send_email(recipient,body,subject="No one" ):
    print(
        f'To: {recipient} \nSubject: {subject}  \nBody: {body}'
    )
send_email('Nicat','book','gvhjklmkjhgfdgchblmk;njgcf')
send_email('Nicat','gvhjklmkjhgfdgchblmk;njgcf')
# Out:
# To: Nicat
# Subject: gvhjklmkjhgfdgchblmk;njgcf
# Body: book
# To: Nicat
# Subject: No one
# Body: gvhjklmkjhgfdgchblmk;njgcf

# %%
def is_positive (x):
    if x>0:
        return True
    elif x==0:
        return True
    return False
is_positive(-7)
# Out:
# False

# %%
def find_long_words ()
